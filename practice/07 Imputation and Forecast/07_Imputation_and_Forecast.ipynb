# %% [markdown]
# ## Анализ и прогнозирование временных рядов методами искусственного интеллекта

# %% [markdown]
# ### **Практическая работа 7. Востановление пропусков и прогноз значений временного ряда.**

# %% [markdown]
# #### **7.1 Аналитечкие методы востановления временного ряда**

# %% [markdown]
# ##### *Краткое описание*

# %% [markdown]
# В данном пункте практической работы вам предстоит познакомиться с базовыми, аналитическими методами восстановления временных рядов.
# Для выполнения данного пункта из каждой группы методов, представленных в ***табл. 7.1*** вам необходимо выбрать по одному методу восстановления ряда. При работе с первой группой, вам необходимо самостоятельно реализовать выбранный метод.
#
# **Табл. 7.1** - Группы аналитических методов восстановления.
# №|Название группы|Модели и методы|
# --|----|----|
# 1|Заполнение существующими значениями ряда|Средним, медианной, Hot-Deck|
# 2|Заполнение на основе близки значений|[Интерполяция](https://scikit-learn.org/stable/auto_examples/linear_model/plot_polynomial_interpolation.html),  [KNNi](https://scikit-learn.org/stable/modules/generated/sklearn.impute.KNNImputer.html)|
# 3|На основе матричных разложений|[CD-Rec](#Fixme:Дат ссылку), [SVD](https://pypi.org/project/fancyimpute/)|

# %% [markdown]
# ##### 7.1.1 Загрузка и подготовка данных
# В данной работе вы будете использовать следующие наборы данных:
# 1. фывфыв
# 2. фывфв

# %%
from pathlib import Path
import numpy as np
import matplotlib.pyplot as plt

# %%
# path_data = Path('datasets')/'madrid.txt'
path_data = r'D:\Study\GitHub\2025_Markov_TimeSeriesCourse\practice\07 Imputation and Forecast\datasets\madrid.txt'
madrid = np.loadtxt(path_data)[:,0]
print(madrid.shape)
# Out:
# (25000,)

# %%
fig, ax =  plt.subplots(figsize=(14,4),ncols=1,nrows=1)
plt.plot(madrid[:])
plt.show()

# %% [markdown]
# Самостоятельно реализуйте функцию, принимающую на вход многомерный временной ряд и возвращающий:
# 1. Все подпоследовательности временного ряда, в которых некоторые значения временного ряда были заменены nan значениями.
# 2. Индексы пропущенных значейни
#
# Процен пппроущенных значений должен регулироваться тедельным параметром.

# %%
import copy
import torch
import random

random.seed(0)

# %%
def add_nan(x, percent = 0.25):
    x_with_nan = copy.deepcopy(x)
    nan_len = x.shape[0] * percent
    nan_counter = 0
    x_with_nan_index = []

    for i in range(x_with_nan.shape[0]):
        if nan_counter <= nan_len and random.randint(0, 1):
            x_with_nan[i] = np.nan
            nan_counter += 1

    return x_with_nan, np.isnan(x_with_nan)

# %%
madrid_with_nan, index = add_nan(madrid)
fig, ax =  plt.subplots(figsize=(14,6),ncols=1,nrows=2)
ax[0].plot(madrid[:1000])
ax[1].plot(madrid_with_nan[:1000])
plt.show()

# %% [markdown]
# ##### 7.1.2 Заполнение существующими значениями ряда

# %%
recovery = {}

# %%
madrid_mean = madrid_with_nan.copy()
madrid_mean[index] = np.nanmean(madrid_mean)
recovery['mean'] = madrid_mean

# %%
fig, ax =  plt.subplots(figsize=(14,3),ncols=1,nrows=1)
ax.plot(madrid[:1000])
ax.plot(madrid_mean[:1000], alpha=0.6)
plt.show()

# %%
madrid_median = madrid_with_nan.copy()
madrid_median[index] = np.nanmedian(madrid_median)

# %%
recovery['median'] = madrid_median

# %%
#madrid_with_nan, index = add_nan(madrid)
fig, ax =  plt.subplots(figsize=(14,3),ncols=1,nrows=1)
ax.plot(madrid[:1000])
ax.plot(madrid_median[:1000], alpha=0.6)
plt.show()

# %% [markdown]
# Самостоятельно реализуйте один метод из первой группы ***табл. 7
# .1*** и проведите востановление данных, сохратив результаты востановления.

# %%
madrid_with_nan.shape
# Out:
# (25000,)

# %%
madrid_with_nan = madrid_with_nan.reshape(-1, 1)
madrid_with_nan.shape
# Out:
# (25000, 1)

# %%
# Hot-Deck

def get_not_nan_row(index, i_indx, x, x_indx, step):

    # index - массив индексов
    # i_indx - индекс строки массива индексов, для заполнения которой ищем значения
    # x - массив значений
    # x_indx - индекс строки массива значений, в которой ищем значения
    # step - шаг

    if x.shape[0] <= x_indx and x_indx >= 0:
        return np.nan

    if ~np.isnan(x[x_indx][index[i_indx]]).all():
        return x[x_indx][index[i_indx]]

    return np.nan


def hot_deck(x, index):
    hot_deck = x.copy()

    for i in range(x.shape[0]):
        if index[i].any():

            for j in range(i, x.shape[0]):
                if ~np.isnan(hot_deck[j][index[i]]).any():
                    next_row = hot_deck[j][index[i]]
                    break

            if ~np.isnan(next_row).any():
                hot_deck[i][index[i]] = next_row
            else:
                for j in range(i, 0, -1):
                    if ~np.isnan(hot_deck[j][index[1]]).any():
                        prev_row = hot_deck[j][index[i]]
                        break

                if ~np.isnan(prev_row).any():
                    hot_deck[i][index[i]] = prev_row

    return hot_deck

# %%
madrid_hot_deck = hot_deck(madrid_with_nan, index)

# %%
recovery['hot_deck'] = madrid_hot_deck

# %%
fig, ax =  plt.subplots(figsize=(14,3),ncols=1,nrows=1)
ax.plot(madrid[:1000])
ax.plot(madrid_hot_deck[:1000], alpha=0.6)
plt.show()

# %% [markdown]
# ##### 7.1.3 Заполнение на основе близких значений

# %% [markdown]
# Используя документацию одного из методов востановления второй группы ***табл. .1*** и проведите востановление данных, сохратив результаты востановления.

# %%
from sklearn.impute import KNNImputer

# %%
madrid_with_nan, index = add_nan(madrid)

# %%
def rolling_window(a, window, intersection=False):
    # result = torch.zeros(size=(a.shape[0],a.shape[1]))
    returns = []
    if intersection:
        for i in range(0, a.shape[0]-window):
            returns.append(a[i:i + window])
    else:
        for i in range(0, a.shape[0],window):
            returns.append(a[i:i + window])
    return np.stack(returns)

# %%
madrid_slice = rolling_window(madrid_with_nan, 100)

imputer = KNNImputer(n_neighbors=10)

madrid_knn_imputer = imputer.fit_transform(madrid_slice)
madrid_knn_imputer = madrid_knn_imputer.ravel()

# %%
recovery['knn_imputer'] = madrid_knn_imputer

# %%
fig, ax =  plt.subplots(figsize=(14,3),ncols=1,nrows=1)
ax.plot(madrid[:1000])
ax.plot(madrid_knn_imputer[:1000], alpha=0.6)
plt.show()

# %% [markdown]
# ##### 7.1.4 Заполнение на матричных преобразований

# %% [markdown]
# Используя документацию одного из методов востановления третей группы ***табл. 7.1*** и проведите востановление данных, сохратив результаты востановления.

# %%
# !pip install fancyimpute
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting fancyimpute
#   Downloading fancyimpute-0.7.0.tar.gz (25 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting knnimpute>=0.1.0 (from fancyimpute)
#   Downloading knnimpute-0.1.0.tar.gz (8.3 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: scikit-learn>=0.24.2 in c:\users\marko\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from fancyimpute) (1.7.2)
# Collecting cvxpy (from fancyimpute)
#   Downloading cvxpy-1.7.3-cp313-cp313-win_amd64.whl.metadata (9.7 kB)
# Collecting cvxopt (from fancyimpute)
#   Downloading cvxopt-1.3.2-cp313-cp313-win_amd64.whl.metadata (1.4 kB)
# Requirement already satisfied: pytest in c:\users\marko\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from fancyimpute) (8.4.2)
# Collecting nose (from fancyimpute)
#   Downloading nose-1.3.7-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: six in c:\users\marko\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from knnimpute>=0.1.0->fancyimpute) (1.17.0)
# Requirement already satisfied: numpy>=1.10 in c:\users\marko\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from knnimpute>=0.1.0->fancyimpute) (2.2.6)
# Requirement already satisfied: scipy>=1.8.0 in c:\users\marko\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from scikit-learn>=0.24.2->fancyimpute) (1.16.2)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\marko\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from scikit-learn>=0.24.2->fancyimpute) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\marko\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from scikit-learn>=0.24.2->fancyimpute) (3.6.0)
# Collecting osqp>=1.0.0 (from cvxpy->fancyimpute)
#   Downloading osqp-1.0.5-cp313-cp313-win_amd64.whl.metadata (2.1 kB)
# Collecting clarabel>=0.5.0 (from cvxpy->fancyimpute)
#   Downloading clarabel-0.11.1-cp39-abi3-win_amd64.whl.metadata (4.9 kB)
# Collecting scs>=3.2.4.post1 (from cvxpy->fancyimpute)
#   Downloading scs-3.2.9-cp313-cp313-win_amd64.whl.metadata (2.8 kB)
# Collecting cffi (from clarabel>=0.5.0->cvxpy->fancyimpute)
#   Downloading cffi-2.0.0-cp313-cp313-win_amd64.whl.metadata (2.6 kB)
# Requirement already satisfied: jinja2 in c:\users\marko\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from osqp>=1.0.0->cvxpy->fancyimpute) (3.1.6)
# Requirement already satisfied: setuptools in c:\users\marko\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from osqp>=1.0.0->cvxpy->fancyimpute) (80.4.0)
# Collecting pycparser (from cffi->clarabel>=0.5.0->cvxpy->fancyimpute)
#   Downloading pycparser-2.23-py3-none-any.whl.metadata (993 bytes)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\marko\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from jinja2->osqp>=1.0.0->cvxpy->fancyimpute) (3.0.3)
# Requirement already satisfied: colorama>=0.4 in c:\users\marko\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from pytest->fancyimpute) (0.4.6)
# Requirement already satisfied: iniconfig>=1 in c:\users\marko\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from pytest->fancyimpute) (2.1.0)
# Requirement already satisfied: packaging>=20 in c:\users\marko\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from pytest->fancyimpute) (25.0)
# Requirement already satisfied: pluggy<2,>=1.5 in c:\users\marko\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from pytest->fancyimpute) (1.6.0)
# Requirement already satisfied: pygments>=2.7.2 in c:\users\marko\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from pytest->fancyimpute) (2.19.2)
# Downloading cvxopt-1.3.2-cp313-cp313-win_amd64.whl (12.8 MB)
#    ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#     --------------------------------------- 0.3/12.8 MB ? eta -:--:--
#     --------------------------------------- 0.3/12.8 MB ? eta -:--:--
#    - -------------------------------------- 0.5/12.8 MB 666.4 kB/s eta 0:00:19
#    - -------------------------------------- 0.5/12.8 MB 666.4 kB/s eta 0:00:19
#    -- ------------------------------------- 0.8/12.8 MB 654.3 kB/s eta 0:00:19
#    -- ------------------------------------- 0.8/12.8 MB 654.3 kB/s eta 0:00:19
#    --- ------------------------------------ 1.0/12.8 MB 650.6 kB/s eta 0:00:19
#    ---- ----------------------------------- 1.3/12.8 MB 688.0 kB/s eta 0:00:17
#    ---- ----------------------------------- 1.3/12.8 MB 688.0 kB/s eta 0:00:17
#    ---- ----------------------------------- 1.6/12.8 MB 720.1 kB/s eta 0:00:16
#    ----- ---------------------------------- 1.8/12.8 MB 748.1 kB/s eta 0:00:15
#    ------ --------------------------------- 2.1/12.8 MB 774.8 kB/s eta 0:00:14
#    ------- -------------------------------- 2.4/12.8 MB 801.3 kB/s eta 0:00:14
#    ------- -------------------------------- 2.4/12.8 MB 801.3 kB/s eta 0:00:14
#    -------- ------------------------------- 2.6/12.8 MB 824.8 kB/s eta 0:00:13
#    -------- ------------------------------- 2.9/12.8 MB 849.0 kB/s eta 0:00:12
#    --------- ------------------------------ 3.1/12.8 MB 871.8 kB/s eta 0:00:12
#    ---------- ----------------------------- 3.4/12.8 MB 892.3 kB/s eta 0:00:11
#    ----------- ---------------------------- 3.7/12.8 MB 913.7 kB/s eta 0:00:11
#    ------------- -------------------------- 4.2/12.8 MB 950.9 kB/s eta 0:00:10
#    ------------- -------------------------- 4.5/12.8 MB 970.8 kB/s eta 0:00:09
#    -------------- ------------------------- 4.7/12.8 MB 988.6 kB/s eta 0:00:09
#    --------------- ------------------------ 5.0/12.8 MB 1.0 MB/s eta 0:00:08
#    ---------------- ----------------------- 5.2/12.8 MB 1.0 MB/s eta 0:00:08
#    ----------------- ---------------------- 5.5/12.8 MB 1.0 MB/s eta 0:00:08
#    ----------------- ---------------------- 5.8/12.8 MB 1.0 MB/s eta 0:00:07
#    ------------------ --------------------- 6.0/12.8 MB 1.0 MB/s eta 0:00:07
#    ------------------- -------------------- 6.3/12.8 MB 1.0 MB/s eta 0:00:07
#    -------------------- ------------------- 6.6/12.8 MB 1.1 MB/s eta 0:00:06
#    --------------------- ------------------ 6.8/12.8 MB 1.1 MB/s eta 0:00:06
#    ---------------------- ----------------- 7.1/12.8 MB 1.1 MB/s eta 0:00:06
#    ----------------------- ---------------- 7.6/12.8 MB 1.1 MB/s eta 0:00:05
#    ------------------------ --------------- 7.9/12.8 MB 1.1 MB/s eta 0:00:05
#    ------------------------- -------------- 8.1/12.8 MB 1.1 MB/s eta 0:00:05
#    -------------------------- ------------- 8.4/12.8 MB 1.1 MB/s eta 0:00:04
#    -------------------------- ------------- 8.7/12.8 MB 1.1 MB/s eta 0:00:04
#    ---------------------------- ----------- 9.2/12.8 MB 1.1 MB/s eta 0:00:04
#    ----------------------------- ---------- 9.4/12.8 MB 1.2 MB/s eta 0:00:03
#    ------------------------------ --------- 9.7/12.8 MB 1.2 MB/s eta 0:00:03
#    ------------------------------- -------- 10.2/12.8 MB 1.2 MB/s eta 0:00:03
#    -------------------------------- ------- 10.5/12.8 MB 1.2 MB/s eta 0:00:02
#    ---------------------------------- ----- 11.0/12.8 MB 1.2 MB/s eta 0:00:02
#    ----------------------------------- ---- 11.3/12.8 MB 1.2 MB/s eta 0:00:02
#    ------------------------------------ --- 11.8/12.8 MB 1.2 MB/s eta 0:00:01
#    ------------------------------------- -- 12.1/12.8 MB 1.2 MB/s eta 0:00:01
#    ---------------------------------------  12.6/12.8 MB 1.3 MB/s eta 0:00:01
#    ---------------------------------------- 12.8/12.8 MB 1.3 MB/s eta 0:00:00
# Downloading cvxpy-1.7.3-cp313-cp313-win_amd64.whl (1.1 MB)
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    --------- ------------------------------ 0.3/1.1 MB ? eta -:--:--
#    --------------------------- ------------ 0.8/1.1 MB 2.1 MB/s eta 0:00:01
#    ---------------------------------------- 1.1/1.1 MB 1.9 MB/s eta 0:00:00
# Downloading clarabel-0.11.1-cp39-abi3-win_amd64.whl (887 kB)
#    ---------------------------------------- 0.0/887.3 kB ? eta -:--:--
#    ----------- ---------------------------- 262.1/887.3 kB ? eta -:--:--
#    ----------------------------------- ---- 786.4/887.3 kB 2.2 MB/s eta 0:00:01
#    ---------------------------------------- 887.3/887.3 kB 2.0 MB/s eta 0:00:00
# Downloading osqp-1.0.5-cp313-cp313-win_amd64.whl (310 kB)
# Downloading scs-3.2.9-cp313-cp313-win_amd64.whl (7.5 MB)
#    ---------------------------------------- 0.0/7.5 MB ? eta -:--:--
#    - -------------------------------------- 0.3/7.5 MB ? eta -:--:--
#    ---- ----------------------------------- 0.8/7.5 MB 2.2 MB/s eta 0:00:04
#    ------- -------------------------------- 1.3/7.5 MB 2.2 MB/s eta 0:00:03
#    --------- ------------------------------ 1.8/7.5 MB 2.2 MB/s eta 0:00:03
#    ------------ --------------------------- 2.4/7.5 MB 2.3 MB/s eta 0:00:03
#    --------------- ------------------------ 2.9/7.5 MB 2.3 MB/s eta 0:00:02
#    ------------------ --------------------- 3.4/7.5 MB 2.3 MB/s eta 0:00:02
#    --------------------- ------------------ 3.9/7.5 MB 2.3 MB/s eta 0:00:02
#    ----------------------- ---------------- 4.5/7.5 MB 2.4 MB/s eta 0:00:02
#    -------------------------- ------------- 5.0/7.5 MB 2.4 MB/s eta 0:00:02
#    ----------------------------- ---------- 5.5/7.5 MB 2.4 MB/s eta 0:00:01
#    --------------------------------- ------ 6.3/7.5 MB 2.4 MB/s eta 0:00:01
#    ------------------------------------ --- 6.8/7.5 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  7.3/7.5 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------- 7.5/7.5 MB 2.5 MB/s eta 0:00:00
# Downloading cffi-2.0.0-cp313-cp313-win_amd64.whl (183 kB)
# Downloading nose-1.3.7-py3-none-any.whl (154 kB)
# Downloading pycparser-2.23-py3-none-any.whl (118 kB)
# Building wheels for collected packages: fancyimpute, knnimpute
#   Building wheel for fancyimpute (pyproject.toml): started
#   Building wheel for fancyimpute (pyproject.toml): finished with status 'done'
#   Created wheel for fancyimpute: filename=fancyimpute-0.7.0-py3-none-any.whl size=29997 sha256=21ddd4835fea0e4d694a58626f70d2d8c9c0254a52bfe18aa368e2daf7b9b74c
#   Stored in directory: c:\users\marko\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local\pip\cache\wheels\f0\8f\ef\e1ffc6bdfa716dc02e4fcd29ec15e5e6814ef6d80421601083
#   Building wheel for knnimpute (pyproject.toml): started
#   Building wheel for knnimpute (pyproject.toml): finished with status 'done'
#   Created wheel for knnimpute: filename=knnimpute-0.1.0-py3-none-any.whl size=11145 sha256=bb9fbcdc74a23a29d7556a2ecd12fdc0570d48a824da8c42a2ed08ccf772f6a2
#   Stored in directory: c:\users\marko\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local\pip\cache\wheels\ff\1b\d6\01492671175ec1802b4b8762aee0fadd98ed4f277b946b045f
# Successfully built fancyimpute knnimpute
# Installing collected packages: nose, pycparser, knnimpute, cvxopt, scs, osqp, cffi, clarabel, cvxpy, fancyimpute
#
#    ----------------------------------------  0/10 [nose]
#    ----------------------------------------  0/10 [nose]
#    ----------------------------------------  0/10 [nose]
#    ----------------------------------------  0/10 [nose]
#    ----------------------------------------  0/10 [nose]
#    ----------------------------------------  0/10 [nose]
#    ----------------------------------------  0/10 [nose]
#    ----------------------------------------  0/10 [nose]
#    ----------------------------------------  0/10 [nose]
#    ----------------------------------------  0/10 [nose]
#    ----------------------------------------  0/10 [nose]
#    ----------------------------------------  0/10 [nose]
#    ----------------------------------------  0/10 [nose]
#    ---- -----------------------------------  1/10 [pycparser]
#    ---- -----------------------------------  1/10 [pycparser]
#    ---- -----------------------------------  1/10 [pycparser]
#    ---- -----------------------------------  1/10 [pycparser]
#    ---- -----------------------------------  1/10 [pycparser]
#    ---- -----------------------------------  1/10 [pycparser]
#    ------------ ---------------------------  3/10 [cvxopt]
#    ------------ ---------------------------  3/10 [cvxopt]
#    ------------ ---------------------------  3/10 [cvxopt]
#    ------------ ---------------------------  3/10 [cvxopt]
#    ------------ ---------------------------  3/10 [cvxopt]
#    ------------ ---------------------------  3/10 [cvxopt]
#    ------------ ---------------------------  3/10 [cvxopt]
#    ---------------- -----------------------  4/10 [scs]
#    ---------------- -----------------------  4/10 [scs]
#    ---------------- -----------------------  4/10 [scs]
#    -------------------- -------------------  5/10 [osqp]
#    -------------------- -------------------  5/10 [osqp]
#    -------------------- -------------------  5/10 [osqp]
#    -------------------- -------------------  5/10 [osqp]
#    -------------------- -------------------  5/10 [osqp]
#    -------------------- -------------------  5/10 [osqp]
#    ------------------------ ---------------  6/10 [cffi]
#    ------------------------ ---------------  6/10 [cffi]
#    ------------------------ ---------------  6/10 [cffi]
#    ------------------------ ---------------  6/10 [cffi]
#    ------------------------ ---------------  6/10 [cffi]
#    -------------------------------- -------  8/10 [cvxpy]
#    -------------------------------- -------  8/10 [cvxpy]
#    -------------------------------- -------  8/10 [cvxpy]
#    -------------------------------- -------  8/10 [cvxpy]
#    -------------------------------- -------  8/10 [cvxpy]
#    -------------------------------- -------  8/10 [cvxpy]
#    -------------------------------- -------  8/10 [cvxpy]
#    -------------------------------- -------  8/10 [cvxpy]
#    -------------------------------- -------  8/10 [cvxpy]
#    -------------------------------- -------  8/10 [cvxpy]
#    -------------------------------- -------  8/10 [cvxpy]
#    -------------------------------- -------  8/10 [cvxpy]
#    -------------------------------- -------  8/10 [cvxpy]
#    -------------------------------- -------  8/10 [cvxpy]
#    -------------------------------- -------  8/10 [cvxpy]
#    -------------------------------- -------  8/10 [cvxpy]
#    -------------------------------- -------  8/10 [cvxpy]
#    -------------------------------- -------  8/10 [cvxpy]
#    -------------------------------- -------  8/10 [cvxpy]
#    -------------------------------- -------  8/10 [cvxpy]
#    -------------------------------- -------  8/10 [cvxpy]
#    -------------------------------- -------  8/10 [cvxpy]
#    -------------------------------- -------  8/10 [cvxpy]
#    -------------------------------- -------  8/10 [cvxpy]
#    -------------------------------- -------  8/10 [cvxpy]
#    -------------------------------- -------  8/10 [cvxpy]
#    -------------------------------- -------  8/10 [cvxpy]
#    -------------------------------- -------  8/10 [cvxpy]
#    -------------------------------- -------  8/10 [cvxpy]
#    -------------------------------- -------  8/10 [cvxpy]
#    -------------------------------- -------  8/10 [cvxpy]
#    -------------------------------- -------  8/10 [cvxpy]
#    -------------------------------- -------  8/10 [cvxpy]
#    -------------------------------- -------  8/10 [cvxpy]
#    -------------------------------- -------  8/10 [cvxpy]
#    -------------------------------- -------  8/10 [cvxpy]
#    -------------------------------- -------  8/10 [cvxpy]
#    -------------------------------- -------  8/10 [cvxpy]
#    -------------------------------- -------  8/10 [cvxpy]
#    -------------------------------- -------  8/10 [cvxpy]
#    -------------------------------- -------  8/10 [cvxpy]
#    -------------------------------- -------  8/10 [cvxpy]
#    -------------------------------- -------  8/10 [cvxpy]
#    -------------------------------- -------  8/10 [cvxpy]
#    -------------------------------- -------  8/10 [cvxpy]
#    -------------------------------- -------  8/10 [cvxpy]
#    -------------------------------- -------  8/10 [cvxpy]
#    -------------------------------- -------  8/10 [cvxpy]
#    -------------------------------- -------  8/10 [cvxpy]
#    -------------------------------- -------  8/10 [cvxpy]
#    -------------------------------- -------  8/10 [cvxpy]
#    -------------------------------- -------  8/10 [cvxpy]
#    -------------------------------- -------  8/10 [cvxpy]
#    -------------------------------- -------  8/10 [cvxpy]
#    -------------------------------- -------  8/10 [cvxpy]
#    -------------------------------- -------  8/10 [cvxpy]
#    -------------------------------- -------  8/10 [cvxpy]
#    -------------------------------- -------  8/10 [cvxpy]
#    -------------------------------- -------  8/10 [cvxpy]
#    -------------------------------- -------  8/10 [cvxpy]
#    -------------------------------- -------  8/10 [cvxpy]
#    -------------------------------- -------  8/10 [cvxpy]
#    -------------------------------- -------  8/10 [cvxpy]
#    -------------------------------- -------  8/10 [cvxpy]
#    -------------------------------- -------  8/10 [cvxpy]
#    -------------------------------- -------  8/10 [cvxpy]
#    -------------------------------- -------  8/10 [cvxpy]
#    -------------------------------- -------  8/10 [cvxpy]
#    -------------------------------- -------  8/10 [cvxpy]
#    -------------------------------- -------  8/10 [cvxpy]
#    -------------------------------- -------  8/10 [cvxpy]
#    -------------------------------- -------  8/10 [cvxpy]
#    -------------------------------- -------  8/10 [cvxpy]
#    -------------------------------- -------  8/10 [cvxpy]
#    -------------------------------- -------  8/10 [cvxpy]
#    -------------------------------- -------  8/10 [cvxpy]
#    -------------------------------- -------  8/10 [cvxpy]
#    -------------------------------- -------  8/10 [cvxpy]
#    -------------------------------- -------  8/10 [cvxpy]
#    -------------------------------- -------  8/10 [cvxpy]
#    -------------------------------- -------  8/10 [cvxpy]
#    -------------------------------- -------  8/10 [cvxpy]
#    -------------------------------- -------  8/10 [cvxpy]
#    -------------------------------- -------  8/10 [cvxpy]
#    -------------------------------- -------  8/10 [cvxpy]
#    -------------------------------- -------  8/10 [cvxpy]
#    -------------------------------- -------  8/10 [cvxpy]
#    -------------------------------- -------  8/10 [cvxpy]
#    -------------------------------- -------  8/10 [cvxpy]
#    -------------------------------- -------  8/10 [cvxpy]
#    -------------------------------- -------  8/10 [cvxpy]
#    -------------------------------- -------  8/10 [cvxpy]
#    -------------------------------- -------  8/10 [cvxpy]
#    -------------------------------- -------  8/10 [cvxpy]
#    -------------------------------- -------  8/10 [cvxpy]
#    -------------------------------- -------  8/10 [cvxpy]
#    -------------------------------- -------  8/10 [cvxpy]
#    -------------------------------- -------  8/10 [cvxpy]
#    -------------------------------- -------  8/10 [cvxpy]
#    -------------------------------- -------  8/10 [cvxpy]
#    -------------------------------- -------  8/10 [cvxpy]
#    -------------------------------- -------  8/10 [cvxpy]
#    -------------------------------- -------  8/10 [cvxpy]
#    -------------------------------- -------  8/10 [cvxpy]
#    -------------------------------- -------  8/10 [cvxpy]
#    -------------------------------- -------  8/10 [cvxpy]
#    -------------------------------- -------  8/10 [cvxpy]
#    -------------------------------- -------  8/10 [cvxpy]
#    -------------------------------- -------  8/10 [cvxpy]
#    -------------------------------- -------  8/10 [cvxpy]
#    -------------------------------- -------  8/10 [cvxpy]
#    -------------------------------- -------  8/10 [cvxpy]
#    -------------------------------- -------  8/10 [cvxpy]
#    -------------------------------- -------  8/10 [cvxpy]
#    -------------------------------- -------  8/10 [cvxpy]
#    -------------------------------- -------  8/10 [cvxpy]
#    -------------------------------- -------  8/10 [cvxpy]
#    -------------------------------- -------  8/10 [cvxpy]
#    -------------------------------- -------  8/10 [cvxpy]
#    -------------------------------- -------  8/10 [cvxpy]
#    -------------------------------- -------  8/10 [cvxpy]
#    -------------------------------- -------  8/10 [cvxpy]
#    ------------------------------------ ---  9/10 [fancyimpute]
#    ---------------------------------------- 10/10 [fancyimpute]
#
# Successfully installed cffi-2.0.0 clarabel-0.11.1 cvxopt-1.3.2 cvxpy-1.7.3 fancyimpute-0.7.0 knnimpute-0.1.0 nose-1.3.7 osqp-1.0.5 pycparser-2.23 scs-3.2.9
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: C:\Users\marko\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
from fancyimpute import IterativeSVD

# %%
solver = IterativeSVD(rank=2)
madrid_iterative_svd = madrid_slice.copy()
madrid_iterative_svd = solver.fit_transform(madrid_iterative_svd)
madrid_iterative_svd = madrid_iterative_svd.ravel()
# Out:
# [IterativeSVD] Iter 1: observed MAE=344.441842
# [IterativeSVD] Iter 2: observed MAE=269.253047
# [IterativeSVD] Iter 3: observed MAE=259.911909
# [IterativeSVD] Iter 4: observed MAE=257.368365
# [IterativeSVD] Iter 5: observed MAE=256.563359
# [IterativeSVD] Iter 6: observed MAE=256.298071
# [IterativeSVD] Iter 7: observed MAE=256.201140
# [IterativeSVD] Iter 8: observed MAE=256.165482
# [IterativeSVD] Iter 9: observed MAE=256.151770
# [IterativeSVD] Iter 10: observed MAE=256.146407
# [IterativeSVD] Iter 11: observed MAE=256.144139
# C:\Users\marko\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\marko\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\marko\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(

# %%
recovery['iterative_svd'] = madrid_iterative_svd

# %%
fig, ax =  plt.subplots(figsize=(14,3),ncols=1,nrows=1)
ax.plot(madrid[:1000])
ax.plot(madrid_iterative_svd[:1000], alpha=0.6)
plt.show()

# %% [markdown]
# ##### 7.1.5 Сравнение результатов востановление.

# %% [markdown]
# Используя следующие библиотеки(список библиотек) отдельно для каждой группы методов постройте методов основные метрики оценки качества постановления.
# На основе метрик отберите лучшие методы постановления метрик и выберите лучшую группу методов. Для лучших методов из каждой группы постройте графики сравнения реальных и восстановленных данных. Объясните результаты и сделайте вывод.

# %%
from sklearn.metrics import mean_squared_error

# %%
metrics = {}

for method in recovery:
    metrics[method] = mean_squared_error(madrid, recovery[method])

metrics
# Out:
# {'mean': 44645.35770742836,
#  'median': 44263.44668,
#  'hot_deck': 23214.8272,
#  'knn_imputer': 12661.4939212,
#  'iterative_svd': 30432.439852753952}

# %% [markdown]
# #### **7.2 Нейросетевые методы востановления временного ряда**

# %% [markdown]
# ##### *Краткое описание*

# %% [markdown]
# В данном пункте практической работы вам предстоит познакомиться с некоторыми нейросетевыми методами восстановления временных рядов.
# Для выполнения данного пункта вам предстоит самостоятельно реализовать структуру нейросетевой, модели основанной на GRU нейронах и сравнить ее с другими нейросетевыми методами восстановления При сравнение с 3 группой из **табл.7. 2** вам необходимо выбрать **один** метод восстановлени.. Основные блоки обработки данных будут реализованы с использованиме Pytorch. Вам не запрещается использовать для реализации Keras.
#
# **т*ал7 5.2** - Нейросетевые методы восстановления.
# №|Название группы|Модели и методы|
# --|-------------|----|
# 1|Линейные нейроны|[Pytorch](https://pytorch.org/docs/stable/generated/torch.nn.Linear.html)|
#  2eкрркуретные нейронны|[Pytorch](https://pytorch.org/docs/stable/generated/torch.nn.GRU.html)|
# 3|Сложные структуры|[SAITS, BRITS, M-RNN](https://github.com/WenjieDu/PyPOTS)|

# %%
recovery_nn = {}

# %%
def add_nan(x, percent = 0.25):
    x_with_nan = copy.deepcopy(x)
    nan_len = x.shape[0] * x.shape[1] * percent
    nan_counter = 0
    x_with_nan_index = []

    for i in range(x_with_nan.shape[0]):
        for j in range(x_with_nan.shape[1]):
            if nan_counter <= nan_len and random.randint(0, 1):
                x_with_nan[i, j] = np.nan
                nan_counter += 1

    return x_with_nan, np.isnan(x_with_nan)

# %% [markdown]
# ##### 7.2.1 Загрузка и подготовка данных

# %%
# path_data = Path('datasets')/'madrid.txt'
path_data = r'D:\Study\GitHub\2025_Markov_TimeSeriesCourse\practice\07 Imputation and Forecast\datasets\madrid.txt'
madrid = np.loadtxt(path_data)[:,:]
print(madrid.shape)
# Out:
# (25000, 10)

# %%
madrid_with_nan, index = add_nan(madrid, 0.25)

# %%
madrid_with_nan.shape
# Out:
# (25000, 10)

# %%
def rolling_window(a, window, intersection=False):
    # result = torch.zeros(size=(a.shape[0],a.shape[1]))
    returns = []
    if intersection:
        for i in range(0, a.shape[0]-window):
            returns.append(a[i:i + window])
    else:
        for i in range(0, a.shape[0],window):
            returns.append(a[i:i + window])
    return np.stack(returns)

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
madrid_normal_with_nan = scaler.fit_transform(madrid_with_nan)

rolling_madrid = rolling_window(madrid_normal_with_nan, 100, True)

train, test = train_test_split(rolling_madrid, shuffle=False, test_size=0.33)

# %% [markdown]
# ##### 7.2.2 Базовая модель востановлениях данных, построенная на нескольких слоях линейных нейроннах

# %% [markdown]
# Вам необходимо будет самостоятельно реализовать:
# 1. инициализацию nan значений какими либо другими значениями.
# 2. замер времени полного обучения и тестирования модели.

# %%
import torch
from torch import nn
from torch.utils.data import DataLoader

# %%
class LinearModel(nn.Module):
    def __init__(self, size_subsequent: int,dim = 1, nums_layers = 3, size_layers = 250):
        super().__init__()

        self.size_subsequent = size_subsequent
        self.nums_layers = nums_layers*dim
        self.dim = dim
        self.size_layers = size_layers

        self.start_layers = nn.Sequential(nn.Flatten(),
                                          nn.Linear(size_subsequent*dim, self.size_layers),
                                          nn.LeakyReLU())
        self.model = nn.ModuleList([
                                        (nn.Sequential(
                                                nn.Linear(self.size_layers, self.size_layers), nn.LeakyReLU()
                                            )
                                        )
                                    for x in torch.arange(nums_layers)])
        self.model = nn.Sequential(*self.model)

        self.output = nn.Sequential(nn.Linear(self.size_layers,size_subsequent*dim),nn.Tanh())

    def forward(self, x):
        x = self.start_layers(x)

        x=self.model(x)
        x=self.output(x)
        return x.reshape(x.shape[0],self.size_subsequent,self.dim)

# %%
model = LinearModel(size_subsequent=train.shape[1],dim=train.shape[2])
optimizer = torch.optim.Adam(model.parameters(),lr=1.0e-3)
loss_func = nn.MSELoss()
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
batch_size = 64
percent = 0.25

train_loader = DataLoader(train,batch_size=batch_size,shuffle=True)
valid_loader = DataLoader(test,batch_size=batch_size,shuffle=True)

print(train.shape,test.shape)
epochs = 25
# Out:
# (16683, 100, 10) (8217, 100, 10)

# %%
model
# Out:
# LinearModel(
#   (start_layers): Sequential(
#     (0): Flatten(start_dim=1, end_dim=-1)
#     (1): Linear(in_features=1000, out_features=250, bias=True)
#     (2): LeakyReLU(negative_slope=0.01)
#   )
#   (model): Sequential(
#     (0): Sequential(
#       (0): Linear(in_features=250, out_features=250, bias=True)
#       (1): LeakyReLU(negative_slope=0.01)
#     )
#     (1): Sequential(
#       (0): Linear(in_features=250, out_features=250, bias=True)
#       (1): LeakyReLU(negative_slope=0.01)
#     )
#     (2): Sequential(
#       (0): Linear(in_features=250, out_features=250, bias=True)
#       (1): LeakyReLU(negative_slope=0.01)
#     )
#   )
#   (output): Sequential(
#     (0): Linear(in_features=250, out_features=1000, bias=True)
#     (1): Tanh()
#   )
# )

# %%
import time
times_model = {}

# %%
def add_nan(x, percent = 0.25):
    x_with_nan = copy.deepcopy(x)
    nan_len = x.shape[0] * x.shape[1] * percent
    nan_counter = 0
    x_with_nan_index = []

    for i in range(x_with_nan.shape[0]):
        for j in range(x_with_nan.shape[1]):
            if nan_counter <= nan_len and random.randint(0, 1):
                x_with_nan[i, j] = np.nan
                nan_counter += 1

    return x_with_nan, np.isnan(x_with_nan.cpu().numpy())

# %%
model=model.to(device)
train_history = []
valid_history = []

start = time.time()
for epoch in np.arange(epochs):
    train_loss =0
    valid_loss =0

    for i, x in enumerate(train_loader):
        if x.shape[0] == batch_size:
            optimizer.zero_grad()
            x = x.to(device).to(torch.float32)
            test_index = np.isnan(x.cpu().numpy())
            X = x.clone()
            X, nan = add_nan(X,percent)
            X[torch.isnan(X)]=0.0
#             nan.to(torch.bool)
#             x = torch.nan_to_num(x, nan=0.0)
            recovery = model(X)
            loss = loss_func(recovery[(nan)&(~test_index)],x[(nan)&(~test_index)])
            train_loss += loss.detach().cpu().item()
            loss.backward()
            optimizer.step()
    train_loss/=(i+1)
    print('valid')
    with torch.no_grad():
        for i, x in enumerate(valid_loader):
            if x.shape[0] == batch_size:
                x = x.to(device).to(torch.float32)
                test_index = np.isnan(x.cpu().numpy())
                X = x.clone()
                X, nan = add_nan(X,percent)
                X[torch.isnan(X)]=0.0
#                 nan.to(torch.bool)
#                 X[torch.isnan(X)]=0.0
                recovery = model(X)
                loss = loss_func(recovery[(nan)&(~test_index)],x[(nan)&(~test_index)])
                valid_loss += loss.detach().cpu().item()
    valid_loss/=(i+1)
    train_history.append(train_loss)
    valid_history.append(valid_loss)
    print(f'epoch:{epoch+1} train:{train_loss}, valid:{valid_loss}')
end = time.time()
# Out:
# valid
# epoch:1 train:0.02348614205745445, valid:0.012090023043890332
# valid
# epoch:2 train:0.013566658692969673, valid:0.011364819806848848
# valid
# epoch:3 train:0.01129601946478831, valid:0.010623435251588044
# valid
# epoch:4 train:0.010616084715972344, valid:0.01015437641289345
# valid
# epoch:5 train:0.010221253894983124, valid:0.00958827462105095
# valid
# epoch:6 train:0.009563266847396834, valid:0.009126943651615649
# valid
# epoch:7 train:0.009194555692374706, valid:0.008825711129854122
# valid
# epoch:8 train:0.00876832503461461, valid:0.008593113204940807
# valid
# epoch:9 train:0.00848988962441797, valid:0.008272216001944256
# valid
# epoch:10 train:0.008151582658105313, valid:0.007493674347191587
# valid
# epoch:11 train:0.007593634704277776, valid:0.006997057067071513
# valid
# epoch:12 train:0.007155799636995541, valid:0.006439212781860847
# valid
# epoch:13 train:0.006768300217644122, valid:0.00633096709024421
# valid
# epoch:14 train:0.006397540372407413, valid:0.006061395875705305
# valid
# epoch:15 train:0.006220790489765876, valid:0.00606976825267423
# valid
# epoch:16 train:0.006002953891567458, valid:0.005737288327988728
# valid
# epoch:17 train:0.0058413023054171564, valid:0.005463247999635546
# valid
# epoch:18 train:0.005700192480237434, valid:0.005396948820485394
# valid
# epoch:19 train:0.005640209301007319, valid:0.005411527144845373
# valid
# epoch:20 train:0.005510580246033454, valid:0.005126267249241125
# valid
# epoch:21 train:0.005346176215408234, valid:0.004954375590147205
# valid
# epoch:22 train:0.0052384056224063094, valid:0.004827638268615155
# valid
# epoch:23 train:0.005160172903460675, valid:0.004869659196643173
# valid
# epoch:24 train:0.004915447406991746, valid:0.004849523587455583
# valid
# epoch:25 train:0.004918925306256646, valid:0.00478337519592786

# %%
times_model['linear']=end-start

# %%
plt.plot(train_history,label='train')
plt.plot(valid_history,label='valid')
plt.legend()
plt.show()

# %%
# base

plt.plot(train_history,label='train')
plt.plot(valid_history,label='valid')
plt.legend()
plt.show()

# %%
test_rolling_madrid = rolling_window(madrid_normal_with_nan, 100, False)
#test = []
with torch.no_grad():
    for idx, batch in enumerate(test_rolling_madrid):
        batch = torch.Tensor(batch).to(device)
        nan = torch.isnan(batch)
        batch[nan]=0.0
        rec = model(batch[None,:])[0].cpu().numpy()
        nan = nan.cpu().numpy()
        test_rolling_madrid[idx][nan]=rec[nan]

# %%
test_madrid_normal = np.vstack(test_rolling_madrid)
test_linear = scaler.inverse_transform(test_madrid_normal)

# %%
recovery_nn['linear'] = test_linear

# %%
from sklearn.metrics import mean_squared_error

# %%
fig, ax =  plt.subplots(figsize=(14,3),ncols=1,nrows=1)

plt.plot(madrid[:1000,0])
plt.plot(test_linear[:1000,0],alpha=0.6)
print(mean_squared_error(madrid[index].reshape(1,-1),test_linear[index].reshape(1,-1)))
# Out:
# 32815.51176520997

# %%
# base

fig, ax =  plt.subplots(figsize=(14,3),ncols=1,nrows=1)

plt.plot(madrid[:1000,0])
plt.plot(test_linear[:1000,0],alpha=0.6)
print(mean_squared_error(madrid[index].reshape(1,-1),test_linear[index].reshape(1,-1)))
# Out:
# 32815.51176520997

# %% [markdown]
# ##### 7.2.3 Реккурентная модель востановлениях данных

# %%
class EncoderGRU(nn.Module):
    def __init__(self, size_subsequent: int, dim = 1, latten_size = 100, hidden_size=100):
        super().__init__()
        self.size_subsequent=size_subsequent
        self.dim = dim
        self.hidden_size = hidden_size
        self.gru = nn.GRU(input_size=dim,
                          hidden_size=self.hidden_size)

        self.latten = nn.Linear(hidden_size*size_subsequent,latten_size)
        self.leaky = nn.LeakyReLU()
        self.fl = nn.Flatten()
    def forward(self, x):
        x, _ = self.gru(x)
        x = self.leaky(x)
        #print(x.shape)
        x = self.fl(x)
        x = self.latten(x)
        return self.leaky(x)

# %%
class DecoderGRU(nn.Module):
    def __init__(self, size_subsequent: int, dim = 1, latten_size = 100, hidden_size=100):
        super().__init__()
        self.size_subsequent=size_subsequent
        self.dim = dim
        self.hidden_size = hidden_size
        self.latten_size=latten_size
        self.gru = nn.GRU(input_size=self.hidden_size,
                          hidden_size=dim)
        self.latten = nn.Linear(latten_size,hidden_size*size_subsequent)
        self.leaky = nn.LeakyReLU()

    def forward(self, x):
        x = self.latten(x)
        x = x.view(-1, self.size_subsequent, self.latten_size)
        x = self.leaky(x)
        x, _ = self.gru(x)
        return self.leaky(x)

# %%
class TimeAE(nn.Module):
    def __init__(self, size_subsequent: int, dim = 1, latten_size = 100, hidden_size=100):
        super().__init__()
        self.encoder = EncoderGRU(size_subsequent=size_subsequent,
                                 dim=dim,
                                 latten_size=latten_size,
                                 hidden_size=hidden_size)
        self.decoder = DecoderGRU(size_subsequent=size_subsequent,
                                 dim=dim,
                                 latten_size=latten_size,
                                 hidden_size=hidden_size)
    def forward(self, x):
        x=self.encoder(x)
        x = self.decoder(x)
        return x

# %%
model = TimeAE(size_subsequent=train.shape[1],dim=train.shape[2])
optimizer = torch.optim.Adam(model.parameters(),lr=1.0e-3)
loss_func = nn.MSELoss()
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
batch_size = 64
percent = 0.25

train_loader = DataLoader(train,batch_size=batch_size,shuffle=True)
valid_loader = DataLoader(test,batch_size=batch_size,shuffle=True)


epochs = 25

# %%
model
# Out:
# TimeAE(
#   (encoder): EncoderGRU(
#     (gru): GRU(10, 100)
#     (latten): Linear(in_features=10000, out_features=100, bias=True)
#     (leaky): LeakyReLU(negative_slope=0.01)
#     (fl): Flatten(start_dim=1, end_dim=-1)
#   )
#   (decoder): DecoderGRU(
#     (gru): GRU(100, 10)
#     (latten): Linear(in_features=100, out_features=10000, bias=True)
#     (leaky): LeakyReLU(negative_slope=0.01)
#   )
# )

# %%
model=model.to(device)
train_history = []
valid_history = []
start = time.time()
for epoch in np.arange(epochs):
    train_loss =0
    valid_loss =0

    for i, x in enumerate(train_loader):
        if x.shape[0]==batch_size:
            optimizer.zero_grad()
            x = x.to(device).to(torch.float32)
            test_index = np.isnan(x.cpu().numpy())
            X = x.clone()
            X, nan = add_nan(X,percent)
            #
            X[torch.isnan(X)]=0.0
            recovery = model(X)
            loss = loss_func(recovery[(nan)&(~test_index)],x[(nan)&(~test_index)])
            train_loss += loss.detach().cpu().item()
            loss.backward()
            optimizer.step()
    train_loss/=(i+1)
    with torch.no_grad():
        for i, x in enumerate(valid_loader):
            if x.shape[0]==batch_size:
                x = x.to(device).to(torch.float32)
                test_index = np.isnan(x.cpu().numpy())
                X = x.clone()
                X, nan = add_nan(X,percent)
                #
                X[torch.isnan(X)]=0.0
                recovery = model(X)
                loss = loss_func(recovery[(nan)&(~test_index)],x[(nan)&(~test_index)])
                valid_loss += loss.detach().cpu().item()
    valid_loss/=(i+1)
    train_history.append(train_loss)
    valid_history.append(valid_loss)
    print(f'epoch:{epoch+1} train:{train_loss}, valid:{valid_loss}')
end = time.time()
# Out:
# epoch:1 train:0.025307742197252098, valid:0.012134226515542629
# epoch:2 train:0.01039291954674255, valid:0.008742797628853672
# epoch:3 train:0.008026288511852423, valid:0.006643185348704804
# epoch:4 train:0.0067362239909040745, valid:0.006094435435654812
# epoch:5 train:0.006057927443849287, valid:0.00533906173668513
# epoch:6 train:0.005468932253404938, valid:0.0048126868665391625
# epoch:7 train:0.005081751935141182, valid:0.004836941798499157
# epoch:8 train:0.004716620409425876, valid:0.004347519335416398
# epoch:9 train:0.004386439982808812, valid:0.004101489307792034
# epoch:10 train:0.004095927590033275, valid:0.004001477105153161
# epoch:11 train:0.003937909970152766, valid:0.003774563220596706
# epoch:12 train:0.003773159181549289, valid:0.0037421871774447287
# epoch:13 train:0.0036150251088799532, valid:0.003586384106802848
# epoch:14 train:0.0034591530367617863, valid:0.003569087791509291
# epoch:15 train:0.0033723883530645993, valid:0.0033369140569553817
# epoch:16 train:0.003260728243874008, valid:0.0033058505469225636
# epoch:17 train:0.0031619403695052496, valid:0.0033154429528544577
# epoch:18 train:0.003080218846613534, valid:0.0031673430136672054
# epoch:19 train:0.002956029231984782, valid:0.0030734783955380434
# epoch:20 train:0.0028660959560581093, valid:0.0030150809253082257
# epoch:21 train:0.0028206854648317185, valid:0.0029904046005663253
# epoch:22 train:0.0027402662163621737, valid:0.0029720881513442643
# epoch:23 train:0.0026808255584018443, valid:0.002908515308933087
# epoch:24 train:0.0025999219588564272, valid:0.0028892564118023992
# epoch:25 train:0.002591638952507941, valid:0.002902237606386459

# %%
plt.plot(train_history,label='train')
plt.plot(valid_history,label='valid')
plt.legend()
plt.show()

# %%
# base

model=model.to(device)
train_history = []
valid_history = []
start = time.time()
for epoch in np.arange(epochs):
    train_loss =0
    valid_loss =0

    for i, x in enumerate(train_loader):
        if x.shape[0]==batch_size:
            optimizer.zero_grad()
            x = x.to(device).to(torch.float32)
            test_index = np.isnan(x.cpu().numpy())
            X = x.clone()
            X, nan = add_nan(X,percent)
            #
            X[torch.isnan(X)]=0.0
            recovery = model(X)
            loss = loss_func(recovery[(nan)&(~test_index)],x[(nan)&(~test_index)])
            train_loss += loss.detach().cpu().item()
            loss.backward()
            optimizer.step()
    train_loss/=(i+1)
    with torch.no_grad():
        for i, x in enumerate(valid_loader):
            if x.shape[0]==batch_size:
                x = x.to(device).to(torch.float32)
                test_index = np.isnan(x.cpu().numpy())
                X = x.clone()
                X, nan = add_nan(X,percent)
                #
                X[torch.isnan(X)]=0.0
                recovery = model(X)
                loss = loss_func(recovery[(nan)&(~test_index)],x[(nan)&(~test_index)])
                valid_loss += loss.detach().cpu().item()
    valid_loss/=(i+1)
    train_history.append(train_loss)
    valid_history.append(valid_loss)
    print(f'epoch:{epoch+1} train:{train_loss}, valid:{valid_loss}')
end = time.time()
# Out:
# epoch:1 train:0.005667857565271215, valid:0.0048371934866200585
# epoch:2 train:0.00420799586293912, valid:0.004097167624507186
# epoch:3 train:0.0035405969621891947, valid:0.003608167110112055
# epoch:4 train:0.003133067681893021, valid:0.0032865865636154895
# epoch:5 train:0.002844720459775107, valid:0.0030663977774192195
# epoch:6 train:0.0026280734780819025, valid:0.0028908427194656097
# epoch:7 train:0.0024395643169652687, valid:0.002762273224720428
# epoch:8 train:0.002310831576114756, valid:0.002648445248762651
# epoch:9 train:0.0021598582576168165, valid:0.002507162047550082
# epoch:10 train:0.0020520448929119955, valid:0.002424571598165257
# epoch:11 train:0.0019568192395221055, valid:0.002385350184284093
# epoch:12 train:0.0018743742489295216, valid:0.0022636219126338413
# epoch:13 train:0.0018025992480124493, valid:0.0022381309459577926
# epoch:14 train:0.001751357673888605, valid:0.002197221281591716
# epoch:15 train:0.0016929136809511146, valid:0.002117336496653021
# epoch:16 train:0.001646642735534815, valid:0.0020511770411575027
# epoch:17 train:0.0015876086636614126, valid:0.0020145903514741464
# epoch:18 train:0.0015538076391101055, valid:0.0020007810450714918
# epoch:19 train:0.0015159790882291236, valid:0.0019655735385351518
# epoch:20 train:0.0014870170717059823, valid:0.001934996402692483
# epoch:21 train:0.0014629344945645024, valid:0.0019042570533794026
# epoch:22 train:0.0014351392017634607, valid:0.0019146379619446952
# epoch:23 train:0.0014176183604096488, valid:0.00186485232868369
# epoch:24 train:0.0013913782532023573, valid:0.0018490065600318733
# epoch:25 train:0.001368902882354127, valid:0.0018317194731342931
# epoch:26 train:0.0013466642222142425, valid:0.0018006087508225857
# epoch:27 train:0.0013333770385818462, valid:0.0018230855163518889
# epoch:28 train:0.0013135319024367236, valid:0.0017810144277592731
# epoch:29 train:0.0012870389206327813, valid:0.001767278980109985
# epoch:30 train:0.001275184848417182, valid:0.001747813082097979
# epoch:31 train:0.0012678609615891202, valid:0.0017714784354289142
# epoch:32 train:0.001254355611183263, valid:0.0017424027007722923
# epoch:33 train:0.001239294847259405, valid:0.001729748811024104
# epoch:34 train:0.0012265690325820012, valid:0.0017241859472854886
# epoch:35 train:0.0012191778340580306, valid:0.001713714836699556
# epoch:36 train:0.0012053452589160182, valid:0.0017178725927721621
# epoch:37 train:0.0011988017896290197, valid:0.001680705125999543
# epoch:38 train:0.0011879894445325566, valid:0.0016757650779155914
# epoch:39 train:0.0011760737680940679, valid:0.0016668402506832697
# epoch:40 train:0.0011655644119371057, valid:0.001705556066504629
# epoch:41 train:0.0011569426918644958, valid:0.0016807086193616422
# epoch:42 train:0.0011532863872339841, valid:0.0016620952442880403
# epoch:43 train:0.001138761623314728, valid:0.0016782453099568916
# epoch:44 train:0.0011324187719719877, valid:0.0016481467322338112
# epoch:45 train:0.0011230841322741347, valid:0.0016307296734952995
# epoch:46 train:0.0011178437121733451, valid:0.0016453813295811415
# epoch:47 train:0.0011071918703530026, valid:0.001630168029128812
# epoch:48 train:0.0011074356264184975, valid:0.0016455832478958507
# epoch:49 train:0.001095724349861101, valid:0.0016421674644256862
# epoch:50 train:0.001090637645264909, valid:0.001621462509411481
# epoch:51 train:0.0010831661832829316, valid:0.0016229615091930987
# epoch:52 train:0.0010759062954435175, valid:0.0016214504031204554
# epoch:53 train:0.00107320239727289, valid:0.0016026566357373497
# epoch:54 train:0.0010698996725138918, valid:0.001610060810840638
# epoch:55 train:0.0010578712855262317, valid:0.0016104646582993888
# epoch:56 train:0.0010549888327910468, valid:0.0016027104313478106
# epoch:57 train:0.001048463754225665, valid:0.001601135928559211
# epoch:58 train:0.0010420855795304465, valid:0.0015953107603442992
# epoch:59 train:0.0010435933067010166, valid:0.001613899264953915
# epoch:60 train:0.0010388768481008595, valid:0.0015808041243590126
# epoch:61 train:0.00102800214988754, valid:0.0015765774955381025
# epoch:62 train:0.0010322307995199386, valid:0.0015746725780903831
# epoch:63 train:0.00102360860977172, valid:0.0015656563350497637
# epoch:64 train:0.001015204734434784, valid:0.001567359682526295
# epoch:65 train:0.0010119174663744638, valid:0.001578217195419147
# epoch:66 train:0.0010134025320314385, valid:0.0015751365815874102
# epoch:67 train:0.0010050949071876533, valid:0.0015724392719711213
# epoch:68 train:0.0010020310131447583, valid:0.0015724693513439261
# epoch:69 train:0.0009972511168919018, valid:0.0015470232144936687
# epoch:70 train:0.0009961685409298402, valid:0.0015706477231930854
# epoch:71 train:0.0009919003112031097, valid:0.0015649314231578578
# epoch:72 train:0.0009809744785632582, valid:0.0015448957100481719
# epoch:73 train:0.0009847193623186443, valid:0.0015517317639418351
# epoch:74 train:0.000983167965575282, valid:0.0015461397611774331
# epoch:75 train:0.000974410233378653, valid:0.0015504505979835755
# epoch:76 train:0.0009709812102614548, valid:0.0015462397456948841
# epoch:77 train:0.0009671033277993458, valid:0.0015469701309118043
# epoch:78 train:0.0009643632840093981, valid:0.0015320026535945114
# epoch:79 train:0.0009653237617085778, valid:0.0015370333774823897
# epoch:80 train:0.000962460886596049, valid:0.0015515535808161133
# epoch:81 train:0.0009600292046918351, valid:0.0015489712895377893
# epoch:82 train:0.0009581661507508706, valid:0.0015390334170773741
# epoch:83 train:0.0009499252140450637, valid:0.0015420413823336247
# epoch:84 train:0.0009542327009362679, valid:0.0015376487551906773
# epoch:85 train:0.0009447208728812549, valid:0.0015372007457149584
# epoch:86 train:0.0009408305246129603, valid:0.00155602987447768
# epoch:87 train:0.0009401118056313403, valid:0.001542696769009958
# epoch:88 train:0.0009336544433162615, valid:0.0015212695507780295
# epoch:89 train:0.0009381620253978647, valid:0.0015523678022111918
# epoch:90 train:0.0009321501559731318, valid:0.0015297242568430398
# epoch:91 train:0.0009320442347566087, valid:0.0015073981020570725
# epoch:92 train:0.0009276046271799881, valid:0.00152922456528154
# epoch:93 train:0.0009312005816170253, valid:0.0015185398849218276
# epoch:94 train:0.0009277866534635396, valid:0.0015211227095447654
# epoch:95 train:0.0009263127110452459, valid:0.001516291147004091
# epoch:96 train:0.0009154978380413633, valid:0.0015143666483187514
# epoch:97 train:0.0009176039094126772, valid:0.001517397214391435
# epoch:98 train:0.000916958295238843, valid:0.0015192465620230912
# epoch:99 train:0.0009132948738854678, valid:0.0015283837461439792
# epoch:100 train:0.0009158381296168314, valid:0.001519506459680292

# %%
# base

plt.plot(train_history,label='train')
plt.plot(valid_history,label='valid')
plt.legend()
plt.show()

# %%
times_model['ae']=end-start

# %%
test_rolling_madrid = rolling_window(madrid_normal_with_nan, 100, False)
#test = []
with torch.no_grad():
    for idx, batch in enumerate(test_rolling_madrid):
        batch = torch.Tensor(batch).to(device)
        nan = torch.isnan(batch)
        #
        batch[torch.isnan(batch)]=0.0
        rec = model(batch[None,:])[0].cpu().numpy()
        nan = nan.cpu().numpy()
        test_rolling_madrid[idx][nan]=rec[nan]

# %%
test_madrid_normal = np.vstack(test_rolling_madrid)
test_ae = scaler.inverse_transform(test_madrid_normal)

# %%
recovery_nn['test_ae'] = test_ae

# %%
fig, ax =  plt.subplots(figsize=(14,3),ncols=1,nrows=1)

plt.plot(madrid[:1000,0])
plt.plot(test_ae[:1000,0],alpha=0.6)
print(mean_squared_error(madrid[index].reshape(1,-1),test_ae[index].reshape(1,-1)))
# Out:
# 16956.515845574628

# %%
# base

fig, ax =  plt.subplots(figsize=(14,3),ncols=1,nrows=1)

plt.plot(madrid[:1000,0])
plt.plot(test_ae[:1000,0],alpha=0.6)
print(mean_squared_error(madrid[index].reshape(1,-1),test_ae[index].reshape(1,-1)))
# Out:
# 7815.347353696892

# %% [markdown]
# ##### 7.2.4 Сложные модели нейросетевого востановлениях данных

# %% [markdown]
# Вам необходимо выбрать одну модель из 3 группы таблицы 7.2 и используя документацию произвести восстановления того же ряда. Произведите замер времени.

# %%
# !pip install pypots==0.0.9
# Out:
# Collecting pypots==0.0.9
#   Downloading pypots-0.0.9-py3-none-any.whl (81 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.6/81.6 kB 2.5 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from pypots==0.0.9) (3.7.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from pypots==0.0.9) (1.23.5)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from pypots==0.0.9) (1.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from pypots==0.0.9) (1.11.3)
# Requirement already satisfied: torch>=1.10 in /usr/local/lib/python3.10/dist-packages (from pypots==0.0.9) (2.1.0+cu118)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.10/dist-packages (from pypots==0.0.9) (2.14.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from pypots==0.0.9) (1.5.3)
# Collecting pycorruptor (from pypots==0.0.9)
#   Downloading pycorruptor-0.0.4-py3-none-any.whl (17 kB)
# Collecting tsdb (from pypots==0.0.9)
#   Downloading tsdb-0.2.1-py3-none-any.whl (24 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.10->pypots==0.0.9) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.10->pypots==0.0.9) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.10->pypots==0.0.9) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.10->pypots==0.0.9) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10->pypots==0.0.9) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.10->pypots==0.0.9) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10->pypots==0.0.9) (2.1.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pypots==0.0.9) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pypots==0.0.9) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pypots==0.0.9) (4.44.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pypots==0.0.9) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pypots==0.0.9) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pypots==0.0.9) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pypots==0.0.9) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pypots==0.0.9) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->pypots==0.0.9) (2023.3.post1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->pypots==0.0.9) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->pypots==0.0.9) (3.2.0)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.10/dist-packages (from tensorboard->pypots==0.0.9) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.10/dist-packages (from tensorboard->pypots==0.0.9) (1.59.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard->pypots==0.0.9) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard->pypots==0.0.9) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard->pypots==0.0.9) (3.5.1)
# Requirement already satisfied: protobuf>=3.19.6 in /usr/local/lib/python3.10/dist-packages (from tensorboard->pypots==0.0.9) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard->pypots==0.0.9) (2.31.0)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard->pypots==0.0.9) (67.7.2)
# Requirement already satisfied: six>1.9 in /usr/local/lib/python3.10/dist-packages (from tensorboard->pypots==0.0.9) (1.16.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard->pypots==0.0.9) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard->pypots==0.0.9) (3.0.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard->pypots==0.0.9) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard->pypots==0.0.9) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard->pypots==0.0.9) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard->pypots==0.0.9) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard->pypots==0.0.9) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard->pypots==0.0.9) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard->pypots==0.0.9) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard->pypots==0.0.9) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard->pypots==0.0.9) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.10->pypots==0.0.9) (1.3.0)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard->pypots==0.0.9) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard->pypots==0.0.9) (3.2.2)
# Installing collected packages: tsdb, pycorruptor, pypots
# Successfully installed pycorruptor-0.0.4 pypots-0.0.9 tsdb-0.2.1

# %%
from pypots.imputation import SAITS

# %%
model= SAITS(n_features=madrid.shape[1],
             n_steps=100,
             device=device,
             d_k=64,
             d_v=64,
             d_model=128,
             d_inner=128,
             n_head=4,
             n_layers=2,
             dropout=0.05,
             epochs=25)
# Out:
# Model initialized successfully. Number of the trainable parameters: 667608

# %%
start = time.time()
model.fit(train,test)
end = time.time()
times_model['saits']=end-start
# Out:
# epoch 0: training loss 0.1416, validating loss 0.0510
# epoch 1: training loss 0.0810, validating loss 0.0417
# epoch 2: training loss 0.0659, validating loss 0.0350
# epoch 3: training loss 0.0572, validating loss 0.0332
# epoch 4: training loss 0.0523, validating loss 0.0318
# epoch 5: training loss 0.0487, validating loss 0.0302
# epoch 6: training loss 0.0460, validating loss 0.0289
# epoch 7: training loss 0.0439, validating loss 0.0281
# epoch 8: training loss 0.0422, validating loss 0.0273
# epoch 9: training loss 0.0409, validating loss 0.0269
# epoch 10: training loss 0.0396, validating loss 0.0275
# epoch 11: training loss 0.0385, validating loss 0.0260
# epoch 12: training loss 0.0377, validating loss 0.0256
# epoch 13: training loss 0.0369, validating loss 0.0255
# epoch 14: training loss 0.0363, validating loss 0.0258
# epoch 15: training loss 0.0358, validating loss 0.0256
# epoch 16: training loss 0.0353, validating loss 0.0258
# epoch 17: training loss 0.0350, validating loss 0.0252
# epoch 18: training loss 0.0348, validating loss 0.0253
# epoch 19: training loss 0.0345, validating loss 0.0253
# epoch 20: training loss 0.0341, validating loss 0.0253
# epoch 21: training loss 0.0338, validating loss 0.0246
# epoch 22: training loss 0.0337, validating loss 0.0248
# epoch 23: training loss 0.0332, validating loss 0.0248
# epoch 24: training loss 0.0332, validating loss 0.0251
# Finished training.

# %%
# base

start = time.time()
model.fit(train,test)
end = time.time()
times_model['saits']=end-start
# Out:
# epoch 0: training loss 0.1332, validating loss 0.0487
# epoch 1: training loss 0.0748, validating loss 0.0418

# %%
test_rolling_madrid = rolling_window(madrid_normal_with_nan, 100, False)
test_rolling_madrid = model.impute(test_rolling_madrid)

# %%
test_madrid_normal = np.vstack(test_rolling_madrid)
test_saits = scaler.inverse_transform(test_madrid_normal)

# %%
recovery_nn['saits'] = test_saits

# %%
fig, ax =  plt.subplots(figsize=(14,3),ncols=1,nrows=1)

plt.plot(madrid[:1000,0])
plt.plot(test_saits[:1000,0],alpha=0.6)
print(mean_squared_error(madrid[index].reshape(1,-1),test_saits[index].reshape(1,-1)))
# Out:
# 7295.100596741347

# %%
# base

fig, ax =  plt.subplots(figsize=(14,3),ncols=1,nrows=1)

plt.plot(madrid[:1000,0])
plt.plot(test_saits[:1000,0],alpha=0.6)
print(mean_squared_error(madrid[index].reshape(1,-1),test_saits[index].reshape(1,-1)))
# Out:
# 4653.035675034267

# %% [markdown]
# ##### 7.2.5 Сравнения результатов.
# Также, как и в пункте 7.1.5 постройте графики сравнения моделей. Дополнительно постройте графики сравнения времени. Сделайте выводы

# %%
n = 3

fig, ax =  plt.subplots(figsize=(14,3*n),ncols=1,nrows=n)

ax[0].plot(madrid[:1000,0])
ax[0].plot(recovery_nn['linear'][:1000,0], alpha=0.6)

ax[1].plot(madrid[:1000,0])
ax[1].plot(recovery_nn['test_ae'][:1000,0], alpha=0.6)

ax[2].plot(madrid[:1000,0])
ax[2].plot(recovery_nn['saits'][:1000,0], alpha=0.6)

# %%
plt.bar(times_model.keys(), times_model.values())
# Out:
# <BarContainer object of 3 artists>

# %% [markdown]
# #### **7.3 Прогноз временного ряда**

# %% [markdown]
# ##### *Краткое описание*

# %% [markdown]
# Используя модель и [ARIMA](реализация) произвидите прогноз ряда на следующие колличество точек: 1, 5, 10.
# Сравните результаты. Постройте графики прогноза и точности прогноза.

# %%
# !pip install statsmodels
# Out:
# Requirement already satisfied: statsmodels in /usr/local/lib/python3.10/dist-packages (0.14.0)
# Requirement already satisfied: numpy>=1.18 in /usr/local/lib/python3.10/dist-packages (from statsmodels) (1.23.5)
# Requirement already satisfied: scipy!=1.9.2,>=1.4 in /usr/local/lib/python3.10/dist-packages (from statsmodels) (1.11.3)
# Requirement already satisfied: pandas>=1.0 in /usr/local/lib/python3.10/dist-packages (from statsmodels) (1.5.3)
# Requirement already satisfied: patsy>=0.5.2 in /usr/local/lib/python3.10/dist-packages (from statsmodels) (0.5.3)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.10/dist-packages (from statsmodels) (23.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0->statsmodels) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0->statsmodels) (2023.3.post1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from patsy>=0.5.2->statsmodels) (1.16.0)

# %%
from statsmodels.tsa.arima.model import ARIMA

model = ARIMA(recovery_nn['saits'][:1000,0], order=(5,1,1))
model_fit = model.fit()

# %%
points_count = [1, 5, 10]
start_points = {1:234, 5:245, 10:256}

mse_err = {}
pred = {}

for i in points_count:
    pred[i] = model_fit.predict(start=start_points[i], end=start_points[i]+i-1)
    mse_err[i] = mean_squared_error(recovery_nn['saits'][start_points[i]:start_points[i]+i, 0], pred[i])

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(14,3))
plt.plot(range(200,300), recovery_nn['saits'][200:300, 0])
# colors = {1:}

for i in points_count:
    plt.plot(range(start_points[i], start_points[i]+i), pred[i], marker='o')

# %%
mse_err
# Out:
# {1: 14356.495006040905, 5: 3242.257637218298, 10: 12057.173361321817}
